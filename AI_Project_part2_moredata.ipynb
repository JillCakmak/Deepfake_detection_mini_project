# %% [markdown]
# ### Deepfake more than images
# Deepfake is often used for videos, which is why we will take our analysis a step further. We will start with a short video of Trevor Noah, and then the same video, deepfaked with Barack obamas Face. First we have to get frames from the videos. Then we will built a simple classifier.
# The data used was provided an Kaggle by VINIT DANTKALE (2020), https://www.kaggle.com/datasets/vinitdantkale/deepfake

# %% [markdown]
# I learned how to abstract frames from a video here: https://thepythoncode.com/article/extract-frames-from-videos-in-python?utm_content=cmp-true  by Abdou Rockikz. We gonna use the MoviePy Library from Open CV

# %%
# !pip install moviepy numpy
# Out:
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 6.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (1.26.3)
# Collecting decorator<5.0,>=4.0.2 (from moviepy)
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from moviepy) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from moviepy) (2.33.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Downloading imageio-ffmpeg-0.4.9.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=8.3.2 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from imageio<3.0,>=2.5->moviepy) (10.2.0)
# Requirement already satisfied: setuptools in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from imageio_ffmpeg>=0.2.0->moviepy) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/miniconda3/envs/AIM/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.11.17)
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Building wheels for collected packages: moviepy, imageio_ffmpeg
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110721 sha256=48dfe4f5143e58af42f7cad62691b273eec2c27fda20031ed45dc74a0e2f8859
#   Stored in directory: /Users/jillcakmak/Library/Caches/pip/wheels/29/15/e4/4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
#   Building wheel for imageio_ffmpeg (setup.py) ... done
#   Created wheel for imageio_ffmpeg: filename=imageio_ffmpeg-0.4.9-py3-none-any.whl size=16367 sha256=ee4088d4ba8ecd3d631fdaa20058de11ccc71f9c2f2ceb363e2d64ce3246ca89
#   Stored in directory: /Users/jillcakmak/Library/Caches/pip/wheels/a0/a2/a5/801b8c9041c8149b486509ade5eb48e3c474d17d31f3746860
# Successfully built moviepy imageio_ffmpeg
# Installing collected packages: proglog, imageio_ffmpeg, decorator, moviepy
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed decorator-4.4.2 imageio_ffmpeg-0.4.9 moviepy-1.0.3 proglog-0.1.10

# %%
#First Imports 
from moviepy.editor import VideoFileClip
import numpy as np
import os
from datetime import timedelta

# %%
# i.e if video of duration 30 seconds, saves 10 frame per second = 300 frames saved in total
SAVING_FRAMES_PER_SECOND = 10

# %%
#Supportive Function 
def format_timedelta(td):
    """Utility function to format timedelta objects in a cool way (e.g 00:00:20.05) 
    omitting microseconds and retaining milliseconds"""
    result = str(td)
    try:
        result, ms = result.split(".")
    except ValueError:
        return (result + ".00").replace(":", "-")
    ms = int(ms)
    ms = round(ms / 1e4)
    return f"{result}.{ms:02}".replace(":", "-")

# %%
#Main Function 
def main(video_file):
    # load the video clip
    video_clip = VideoFileClip(video_file)
    # make a folder by the name of the video file
    filename, _ = os.path.splitext(video_file)
    filename += "-moviepy_2"
    if not os.path.isdir(filename):
        os.mkdir(filename)

    # if the SAVING_FRAMES_PER_SECOND is above video FPS, then set it to FPS (as maximum)
    saving_frames_per_second = min(video_clip.fps, SAVING_FRAMES_PER_SECOND)
    # if SAVING_FRAMES_PER_SECOND is set to 0, step is 1/fps, else 1/SAVING_FRAMES_PER_SECOND
    step = 1 / video_clip.fps if saving_frames_per_second == 0 else 1 / saving_frames_per_second
    # iterate over each possible frame
    for current_duration in np.arange(0, video_clip.duration, step):
        # format the file name and save it
        frame_duration_formatted = format_timedelta(timedelta(seconds=current_duration))
        frame_filename = os.path.join(filename, f"frame{frame_duration_formatted}.jpg")
        # save the frame with the current duration
        video_clip.save_frame(frame_filename, current_duration)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/Fake_Obama.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/FAKE_TrumandBiden.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "data/Fake_Trump.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/fakevideo.mp4"
    main(video_file)

# %% [markdown]
# Let's do the same with our Real Video

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/realvideo.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/REAL_Trump.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/Real_Obama.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/Real_Obama_equivalent.mp4"
    main(video_file)

# %%
if __name__ == "__main__":
    import sys
    video_file = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/REAL_Biden.mp4"
    main(video_file)

# %% [markdown]
# Now before I can proceed I have to merge all my data into only 2 folders (fake and real) as I had previously, instead of 7 different ones. For that I will use 'shutil' I found instructions via Geeks for Geeks where I took the basic code from, you can find it here: https://www.geeksforgeeks.org/how-to-merge-multiple-folders-into-one-folder-using-python/

# %%
import shutil 
import os

# %%
# current folder path 
current_folder= os.getcwd()

# list of folders to be merged 
list_dir = ['/Users/jillcakmak/Documents/GitHub/AI_Project/data/Fake_Obama-moviepy_2', '/Users/jillcakmak/Documents/GitHub/AI_Project/data/FAKE_TrumandBiden-moviepy_2', '/Users/jillcakmak/Documents/GitHub/AI_Project/data/Fake_Trump-moviepy_2','/Users/jillcakmak/Documents/GitHub/AI_Project/data/fakevideo-moviepy_2']  

# enumerate on list_dir to get the 
# content of all the folders ans store it in a dictionary 
content_list = {} 
for index, val in enumerate(list_dir): 
	path = os.path.join(current_folder, val) 
	content_list[ list_dir[index] ] = os.listdir(path)

# %%
# Function to create new folder if not exists 
def make_new_folder(folder_name, parent_folder_path): 
	
	# Path 
	path = os.path.join(parent_folder_path, folder_name) 
	
	# Create the folder 
	# 'new_folder' in 
	# parent_folder 
	try: 
		
		# mode of the folder 
		mode = 0o777

		# Create folder 
		os.mkdir(path, mode) 
		
	except OSError as error: 
		print(error) 

# folder in which all the content 
# will be merged 
merge_folder = "fake_data_merge_folder"

# merge_folder path - current_folder 
# + merge_folder 
merge_folder_path = os.path.join(current_folder, merge_folder) 

# create merge_folder if not exists 
make_new_folder(merge_folder, current_folder)

# %%
#I an encountered an error because the frames were saved with the same titles via moviepy, so I have to rename them 

# loop through the list of folders
for sub_dir in content_list:

    # loop through the contents of the
    # list of folders
    for contents in content_list[sub_dir]:

        # make the path of the content to move
        path_to_content = sub_dir + "/" + contents

        # make the path with the current folder
        dir_to_move = os.path.join(current_folder, path_to_content)

        # Check if the file already exists in the merge_folder
        if os.path.exists(os.path.join(merge_folder_path, contents)):
            #This solution is from chat_gpt as I couldn't find another way of how to rename my frames saved by moviepy 
            # Split the filename and extension
            base, extension = os.path.splitext(contents)
            index = 1
            # Keep trying new names until a unique name is found
            while True:
                new_name = f"{base}_{index}{extension}"
                new_path = os.path.join(merge_folder_path, new_name)
                if not os.path.exists(new_path):
                    break
                index += 1
            print(f"File {contents} already exists in {merge_folder_path}. Renaming to {new_name}")
            # Move the file with the new name
            shutil.move(dir_to_move, new_path)
        else:
            # Move the file
            shutil.move(dir_to_move, merge_folder_path)
# Out:
# File frame0-00-05.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.90_1.jpg
# File frame0-00-02.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.70_1.jpg
# File frame0-00-06.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-06.00_1.jpg
# File frame0-00-03.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.30_1.jpg
# File frame0-00-00.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.60_1.jpg
# File frame0-00-04.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.10_1.jpg
# File frame0-00-01.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.20_1.jpg
# File frame0-00-05.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.50_1.jpg
# File frame0-00-05.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.40_1.jpg
# File frame0-00-01.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.30_1.jpg
# File frame0-00-04.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.00_1.jpg
# File frame0-00-00.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.70_1.jpg
# File frame0-00-03.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.20_1.jpg
# File frame0-00-06.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-06.10_1.jpg
# File frame0-00-02.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.60_1.jpg
# File frame0-00-05.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.80_1.jpg
# File frame0-00-02.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.10_1.jpg
# File frame0-00-03.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.50_1.jpg
# File frame0-00-00.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.00_1.jpg
# File frame0-00-04.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.70_1.jpg
# File frame0-00-01.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.40_1.jpg
# File frame0-00-05.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.30_1.jpg
# File frame0-00-03.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.90_1.jpg
# File frame0-00-01.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.80_1.jpg
# File frame0-00-01.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.90_1.jpg
# File frame0-00-03.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.80_1.jpg
# File frame0-00-05.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.20_1.jpg
# File frame0-00-01.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.50_1.jpg
# File frame0-00-04.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.60_1.jpg
# File frame0-00-00.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.10_1.jpg
# File frame0-00-03.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.40_1.jpg
# File frame0-00-02.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.00_1.jpg
# File frame0-00-05.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.10_1.jpg
# File frame0-00-01.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.60_1.jpg
# File frame0-00-04.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.50_1.jpg
# File frame0-00-00.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.20_1.jpg
# File frame0-00-03.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.70_1.jpg
# File frame0-00-06.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-06.40_1.jpg
# File frame0-00-02.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.30_1.jpg
# File frame0-00-04.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.90_1.jpg
# File frame0-00-04.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.80_1.jpg
# File frame0-00-02.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.20_1.jpg
# File frame0-00-03.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.60_1.jpg
# File frame0-00-00.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.30_1.jpg
# File frame0-00-04.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.40_1.jpg
# File frame0-00-01.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.70_1.jpg
# File frame0-00-05.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.00_1.jpg
# File frame0-00-00.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.80_1.jpg
# File frame0-00-02.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.90_1.jpg
# File frame0-00-05.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.70_1.jpg
# File frame0-00-01.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.00_1.jpg
# File frame0-00-04.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.30_1.jpg
# File frame0-00-00.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.40_1.jpg
# File frame0-00-03.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.10_1.jpg
# File frame0-00-06.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-06.20_1.jpg
# File frame0-00-02.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.50_1.jpg
# File frame0-00-02.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.40_1.jpg
# File frame0-00-06.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-06.30_1.jpg
# File frame0-00-03.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-03.00_1.jpg
# File frame0-00-00.50.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.50_1.jpg
# File frame0-00-04.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-04.20_1.jpg
# File frame0-00-01.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-01.10_1.jpg
# File frame0-00-05.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-05.60_1.jpg
# File frame0-00-02.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-02.80_1.jpg
# File frame0-00-00.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/fake_data_merge_folder. Renaming to frame0-00-00.90_1.jpg

# %%
# # loop through the list of folders
# for sub_dir in content_list:

#     # loop through the contents of the
#     # list of folders
#     for contents in content_list[sub_dir]:

#         # make the path of the content to move
#         path_to_content = sub_dir + "/" + contents

#         # make the path with the current folder
#         dir_to_move = os.path.join(current_folder, path_to_content)
#         #I an encountered an error implement an if statement 

#         # Check if the file already exists in the merge_folder
#         if os.path.exists(os.path.join(merge_folder_path, contents)):
#             print(f"File {contents} already exists in {merge_folder_path}. Skipping...")
#         else:
#             # move the file
#             shutil.move(dir_to_move, merge_folder_path)

# %%
#It worked with the Chat_GPT solution, as it skipped over the frame names which where already given and tried to rename it to something unqique,
# I was reading more about that suggested piece of code here: 

#Lets to the same again for the real videos

# %%
# current folder path 
current_folder= os.getcwd()

# list of folders to be merged 
list_dir = ['/Users/jillcakmak/Documents/GitHub/AI_Project/data/REAL_Biden-moviepy_2', '/Users/jillcakmak/Documents/GitHub/AI_Project/data/Real_Obama_equivalent-moviepy_2', '/Users/jillcakmak/Documents/GitHub/AI_Project/data/Real_Obama-moviepy_2','/Users/jillcakmak/Documents/GitHub/AI_Project/data/REAL_Trump-moviepy_2', '/Users/jillcakmak/Documents/GitHub/AI_Project/data/realvideo-moviepy_2']  

# enumerate on list_dir to get the 
# content of all the folders ans store it in a dictionary 
content_list = {} 
for index, val in enumerate(list_dir): 
	path = os.path.join(current_folder, val) 
	content_list[ list_dir[index] ] = os.listdir(path)

# %%
# Function to create new folder if not exists 
def make_new_folder(folder_name, parent_folder_path): 
	
	# Path 
	path = os.path.join(parent_folder_path, folder_name) 
	
	# Create the folder 
	# 'new_folder' in 
	# parent_folder 
	try: 
		
		# mode of the folder 
		mode = 0o777

		# Create folder 
		os.mkdir(path, mode) 
		
	except OSError as error: 
		print(error) 

# folder in which all the content 
# will be merged 
merge_folder = "real_data_merge_folder"

# merge_folder path - current_folder 
# + merge_folder 
merge_folder_path = os.path.join(current_folder, merge_folder) 

# create merge_folder if not exists 
make_new_folder(merge_folder, current_folder)

# %%
#I an encountered an error because the frames were saved with the same titles via moviepy, so I have to rename them 

# loop through the list of folders
for sub_dir in content_list:

    # loop through the contents of the
    # list of folders
    for contents in content_list[sub_dir]:

        # make the path of the content to move
        path_to_content = sub_dir + "/" + contents

        # make the path with the current folder
        dir_to_move = os.path.join(current_folder, path_to_content)

        # Check if the file already exists in the merge_folder
        if os.path.exists(os.path.join(merge_folder_path, contents)):
            #This solution is from chat_gpt as I couldn't find another way of how to rename my frames saved by moviepy 
            # Split the filename and extension
            base, extension = os.path.splitext(contents)
            index = 1
            # Keep trying new names until a unique name is found
            while True:
                new_name = f"{base}_{index}{extension}"
                new_path = os.path.join(merge_folder_path, new_name)
                if not os.path.exists(new_path):
                    break
                index += 1
            print(f"File {contents} already exists in {merge_folder_path}. Renaming to {new_name}")
            # Move the file with the new name
            shutil.move(dir_to_move, new_path)
        else:
            # Move the file
            shutil.move(dir_to_move, merge_folder_path)
# Out:
# File frame0-00-15.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-15.80_1.jpg
# File frame0-00-19.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-19.80_1.jpg
# File frame0-00-07.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-07.80_1.jpg
# File frame0-00-21.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-21.90_1.jpg
# File frame0-00-09.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-09.90_1.jpg
# File frame0-00-17.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-17.90_1.jpg
# File frame0-00-23.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-23.80_1.jpg
# File frame0-00-05.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-05.90_1.jpg
# File frame0-00-24.60.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-24.60_1.jpg
# File frame0-00-11.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-11.30_1.jpg
# File frame0-00-18.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-18.00_1.jpg
# File frame0-00-02.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-02.70_1.jpg
# File frame0-00-20.10.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-20.10_1.jpg
# File frame0-00-29.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-29.20_1.jpg
# File frame0-00-15.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-15.40_1.jpg
# File frame0-00-06.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-06.00_1.jpg
# File frame0-00-25.20.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-25.20_1.jpg
# File frame0-00-03.30.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-03.30_1.jpg
# File frame0-00-19.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-19.40_1.jpg
# File frame0-00-10.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00
jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-01-00.30_2.jpg
# File frame0-01-09.00.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-01-09.00_2.jpg
# File frame0-00-34.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-34.80_3.jpg
# File frame0-01-13.70.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-01-13.70_1.jpg
# File frame0-00-49.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-49.80_3.jpg
# File frame0-00-12.90.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-12.90_4.jpg
# File frame0-01-04.40.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-01-04.40_2.jpg
# File frame0-00-57.80.jpg already exists in /Users/jillcakmak/Documents/GitHub/AI_Project/real_data_merge_folder. Renaming to frame0-00-57.80_2.jpg

# %% [markdown]
# Now that we have 2 directories with fake and real images of the video we can built a simple Classifier as we learned in class. After that we can check if image detection might improve the classifier

# %%
#Imports first 
import torch
import torchvision
import cv2
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.utils as vutils
import torchvision.transforms as transforms
import argparse

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from imutils import paths
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from sklearn.utils import resample
from sklearn.metrics import classification_report

# %%
#I moved the frames of the video snippets into a new folder 'Video_data'
device = 'mps'
momentum = 0.9
num_epochs = 20
num_classes = 2 #fake & real 
val_size = 0.3
batch_size = 100
learn_rate = 0.001
freeze_lower_layers = True
data_path = "/Users/jillcakmak/Documents/GitHub/AI_Project/data/Merged_files"

# %%
#next we define training and validation 
train_transform = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomAffine(degrees=(-30,30),translate=(0.15,0.15),scale=(0.85,1.15)),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.RandomResizedCrop(size=(224, 224), antialias=True),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %%
val_transform = transforms.Compose(
    [   
        torchvision.transforms.Resize(224, antialias=True),
        torchvision.transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %%
#Lets split our data by train, test and validation 
dataset = ImageFolder(data_path, transform=train_transform)
num_classes = 2 #len(dataset.classes)

# Get length of dataset and indicies
num_train = len(dataset)
indices = list(range(num_train))

# Get train / val split for data points
train_indices, test_indices = train_test_split(indices, test_size=val_size, random_state=42)
train_indices, val_indices = train_test_split(train_indices, test_size=val_size, random_state=42)

# Override dataset classes to only be samples for each split
train_subset = torch.utils.data.Subset(dataset, train_indices)
test_subset = torch.utils.data.Subset(dataset, test_indices)
val_subset = torch.utils.data.Subset(dataset, val_indices)

# Create data loaders
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

# %%
#Now we visualise our training dataset, which should only be images of the Trevor Noah /Barack Obama Deepfake 
# Plot some training images
real_batch = next(iter(train_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Video Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
# Plot some validation images
real_batch = next(iter(val_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Validation Video Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
#Now we will use the pretrained model from week 3 
model = torchvision.models.resnet18(weights='IMAGENET1K_V1')

# Freeze weights
if freeze_lower_layers == True:
    for param in model.parameters():
        param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, num_classes)
model.to(device)

#this code was originally sources from: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html as described in class
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
# Cross entropy loss for training classification
criterion = nn.CrossEntropyLoss()

# Stochastic gradient descent loss
optimizer = optim.SGD(model.parameters(), lr=learn_rate, momentum=momentum)

# %%
#Now we will train and calculate Validation loss. As we learned ideally we should stop the model when the validation loss goes up and training goes down 
train_losses = []
val_losses = []

best_loss = 100000
for epoch in range(num_epochs): 
    train_loss = 0.0
    
    # Training loop
    for i, data in enumerate(train_loader, 0):
        # Get data
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # Process data
        outputs = model(inputs)
        
        # Calculate loss
        loss = criterion(outputs, labels)
        
        # Update model weights
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        train_loss += loss.item()
    
    # Validation loop
    with torch.no_grad():
        val_loss = 0.0
        for i, data in enumerate(val_loader, 0):
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
    
    # Normalise cumulative losses to dataset size
    train_loss = train_loss / len(train_loader)
    val_loss = val_loss / len(val_loader)
    
    # Added cumulative losses to lists for later display
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    print(f'Epoch {epoch + 1}, train loss: {train_loss:.3f}, val loss: {val_loss:.3f}')
    
    # if validation score is lowest so far, save the model, ideal model 
    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(model.state_dict(), 'best_finetuned_increased_video_model.pt')
# Out:
# Epoch 1, train loss: 0.427, val loss: 0.466
# Epoch 2, train loss: 0.287, val loss: 0.263
# Epoch 3, train loss: 0.222, val loss: 0.233
# Epoch 4, train loss: 0.203, val loss: 0.214
# Epoch 5, train loss: 0.186, val loss: 0.217
# Epoch 6, train loss: 0.188, val loss: 0.209
# Epoch 7, train loss: 0.188, val loss: 0.207
# Epoch 8, train loss: 0.184, val loss: 0.197
# Epoch 9, train loss: 0.174, val loss: 0.188
# Epoch 10, train loss: 0.178, val loss: 0.201
# Epoch 11, train loss: 0.178, val loss: 0.195
# Epoch 12, train loss: 0.166, val loss: 0.185
# Epoch 13, train loss: 0.161, val loss: 0.185
# Epoch 14, train loss: 0.173, val loss: 0.183
# Epoch 15, train loss: 0.167, val loss: 0.195
# Epoch 16, train loss: 0.159, val loss: 0.176
# Epoch 17, train loss: 0.161, val loss: 0.177
# Epoch 18, train loss: 0.162, val loss: 0.163
# Epoch 19, train loss: 0.150, val loss: 0.168
# Epoch 20, train loss: 0.167, val loss: 0.169

# %%
#Now we will plot the outcome (Training and Validation)
#Plotting Training and Validation loss 
plt.figure(figsize=(10,5))
plt.title("Train vs validation loss extended Video data")
plt.plot(train_losses,label="train")
plt.plot(val_losses,label="val")
plt.xlabel("epochs")
plt.ylabel("cumulative loss")
plt.legend()
plt.show()

# %%
    # Training loop from above but altered to test 
total= 0
correct = 0

for i, data in enumerate(test_loader, 0):
        # Get data
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # Process data
        outputs = model(inputs)

        # Compute predictions #this part is from chat-gpt 
        _, predicted = torch.max(outputs.data, 1)

         # Calculate accuracy
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# %%
# Print the accuracy
print('Accuracy of the network on the extended video test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the extended video test images: 92 %

# %% [markdown]
# #### Conclusion
# **Our Accuracy is 92% what is incredible high especially compared to the previous model which is why I had to check my data**. It turned out that my obama video (real) did not render correctly, it shows a black screen, additionally the fake video is not in the merge folder. That said, I will do the same thing again, rendering the obama video again, in case it doesn't work I would remove it from the dataset entirely as this can cause too much error in my classifier. Now we do not know if it classified by the black screen instead of the person etc.
#
# **Update** Rendering worked in the new notebook, accuraccy was heavily influenced by the wrong data in this notebook.
